# %%
import cv2
from google.colab.patches import cv2_imshow
imagem = cv2.imread('/content/drive/MyDrive/Projeto Cassandra/Captura de tela 2023-12-17 142207.png')
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=917x146>

# %%
imagem = cv2.imread('/content/drive/MyDrive/Projeto Cassandra/Captura de tela 2023-12-17 143022.png')
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=1217x155>

# %%
imagem = cv2.imread('/content/drive/MyDrive/Projeto Cassandra/Captura de tela 2023-12-17 143127.png')
cv2_imshow(imagem)
imagem = cv2.imread('/content/drive/MyDrive/Projeto Cassandra/Captura de tela 2023-12-17 143728.png')
cv2_imshow(imagem)
imagem = cv2.imread('/content/drive/MyDrive/Projeto Cassandra/Captura de tela 2023-12-17 144116.png')
cv2_imshow(imagem)
imagem = cv2.imread('/content/drive/MyDrive/Projeto Cassandra/Captura de tela 2023-12-17 144126.png')
cv2_imshow(imagem)
imagem = cv2.imread('/content/drive/MyDrive/Projeto Cassandra/Captura de tela 2023-12-18 213419.png')
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=1906x232>
# <PIL.Image.Image image mode=RGB size=693x85>
# <PIL.Image.Image image mode=RGB size=933x331>
# <PIL.Image.Image image mode=RGB size=1005x672>
# <PIL.Image.Image image mode=RGB size=1452x159>
